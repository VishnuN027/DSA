# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('fifa_cleaned.csv')

# %%
data
# Out:
#            id            name  age  height_cm  weight_kgs  positions  \
# 0      158023        L. Messi   31     170.18        72.1   CF,RW,ST
# 1      190460      C. Eriksen   27     154.94        76.2  CAM,RM,CM
# 2      195864        P. Pogba   25     190.50        83.9     CM,CAM
# 3      198219      L. Insigne   27     162.56        59.0      LW,ST
# 4      201024    K. Koulibaly   27     187.96        88.9         CB
# ...       ...             ...  ...        ...         ...        ...
# 17949  204322     R. McKenzie   25     175.26        74.8  RM,CAM,CM
# 17950  239762       M. Sipľak   23     182.88        79.8         LB
# 17951  235155      J. Bekkema   22     185.42        89.8         GK
# 17952  244883      A. Al Yami   21     175.26        64.9      ST,LM
# 17953  247187  Júnior Brumado   19     190.50        79.8         ST
#
#         nationality  overall_rating  potential   value_euro  wage_euro  \
# 0         Argentina              94         94  110500000.0   565000.0
# 1           Denmark              88         89   69500000.0   205000.0
# 2            France              88         91   73000000.0   255000.0
# 3             Italy              88         88   62000000.0   165000.0
# 4           Senegal              88         91   60000000.0   135000.0
# ...             ...             ...        ...          ...        ...
# 17949      Scotland              67         70     975000.0     3000.0
# 17950      Slovakia              59         67     190000.0     1000.0
# 17951   Netherlands              59         67     170000.0     1000.0
# 17952  Saudi Arabia              59         71     280000.0     4000.0
# 17953        Brazil              59         75     325000.0     2000.0
#
#       preferred_foot  international_reputation(1-5)  weak_foot(1-5)  \
# 0               Left                              5               4
# 1              Right                              3               5
# 2              Right                              4               4
# 3              Right                              3               4
# 4              Right                              3               3
# ...              ...                            ...             ...
# 17949          Right                              1               3
# 17950           Left                              1               3
# 17951          Right                              1               1
# 17952          Right                              1               4
# 17953          Right                              1               4
#
#        skill_moves(1-5)       work_rate  release_clause_euro  \
# 0                     4     Medium/ Low          226500000.0
# 1                     4    High/ Medium          133800000.0
# 2                     5    High/ Medium          144200000.0
# 3                     4    High/ Medium          105400000.0
# 4                     2      High/ High          106500000.0
# ...                 ...             ...                  ...
# 17949                 3    High/ Medium            1800000.0
# 17950                 2    Medium/ High             295000.0
# 17951                 1  Medium/ Medium             289000.0
# 17952                 3     Medium/ Low             532000.0
# 17953                 2  Medium/ Medium             626000.0
#
#                club_team
# 0           FC Barcelona
# 1      Tottenham Hotspur
# 2      Manchester United
# 3                 Napoli
# 4                 Napoli
# ...                  ...
# 17949         Kilmarnock
# 17950           Cracovia
# 17951      SC Heerenveen
# 17952           Al Hilal
# 17953     FC Midtjylland
#
# [17954 rows x 18 columns]

# %%
data= pd.read_csv('fifa_cleaned.csv',index_col='id')

# %%
data.head()
# Out:
#                 name  age  height_cm  weight_kgs  positions nationality  \
# id
# 158023      L. Messi   31     170.18        72.1   CF,RW,ST   Argentina
# 190460    C. Eriksen   27     154.94        76.2  CAM,RM,CM     Denmark
# 195864      P. Pogba   25     190.50        83.9     CM,CAM      France
# 198219    L. Insigne   27     162.56        59.0      LW,ST       Italy
# 201024  K. Koulibaly   27     187.96        88.9         CB     Senegal
#
#         overall_rating  potential   value_euro  wage_euro preferred_foot  \
# id
# 158023              94         94  110500000.0   565000.0           Left
# 190460              88         89   69500000.0   205000.0          Right
# 195864              88         91   73000000.0   255000.0          Right
# 198219              88         88   62000000.0   165000.0          Right
# 201024              88         91   60000000.0   135000.0          Right
#
#         international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  \
# id
# 158023                              5               4                 4
# 190460                              3               5                 4
# 195864                              4               4                 5
# 198219                              3               4                 4
# 201024                              3               3                 2
#
#            work_rate  release_clause_euro          club_team
# id
# 158023   Medium/ Low          226500000.0       FC Barcelona
# 190460  High/ Medium          133800000.0  Tottenham Hotspur
# 195864  High/ Medium          144200000.0  Manchester United
# 198219  High/ Medium          105400000.0             Napoli
# 201024    High/ High          106500000.0             Napoli

# %%
data.isna().sum()
# Out:
# name                                0
# age                                 0
# height_cm                           0
# weight_kgs                          0
# positions                           0
# nationality                         0
# overall_rating                      0
# potential                           0
# value_euro                        255
# wage_euro                         246
# preferred_foot                      0
# international_reputation(1-5)       0
# weak_foot(1-5)                      0
# skill_moves(1-5)                    0
# work_rate                           0
# release_clause_euro              1837
# club_team                          14
# dtype: int64

# %%
data.shape
# Out:
# (17954, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17954 entries, 158023 to 247187
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   age                            17954 non-null  int64
#  2   height_cm                      17954 non-null  float64
#  3   weight_kgs                     17954 non-null  float64
#  4   positions                      17954 non-null  object
#  5   nationality                    17954 non-null  object
#  6   overall_rating                 17954 non-null  int64
#  7   potential                      17954 non-null  int64
#  8   value_euro                     17699 non-null  float64
#  9   wage_euro                      17708 non-null  float64
#  10  preferred_foot                 17954 non-null  object
#  11  international_reputation(1-5)  17954 non-null  int64
#  12  weak_foot(1-5)                 17954 non-null  int64
#  13  skill_moves(1-5)               17954 non-null  int64
#  14  work_rate                      17954 non-null  object
#  15  release_clause_euro            16117 non-null  float64
#  16  club_team                      17940 non-null  object
# dtypes: float64(5), int64(6), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
#  null values are presenting

# %%
data['value_euro']= data['value_euro'].fillna(data['value_euro'].median())
data['wage_euro']= data['wage_euro'].fillna(data['wage_euro'].median())


data['release_clause_euro']= data['release_clause_euro'].fillna(data['release_clause_euro'].mode().loc[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17954 entries, 158023 to 247187
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   age                            17954 non-null  int64
#  2   height_cm                      17954 non-null  float64
#  3   weight_kgs                     17954 non-null  float64
#  4   positions                      17954 non-null  object
#  5   nationality                    17954 non-null  object
#  6   overall_rating                 17954 non-null  int64
#  7   potential                      17954 non-null  int64
#  8   value_euro                     17954 non-null  float64
#  9   wage_euro                      17954 non-null  float64
#  10  preferred_foot                 17954 non-null  object
#  11  international_reputation(1-5)  17954 non-null  int64
#  12  weak_foot(1-5)                 17954 non-null  int64
#  13  skill_moves(1-5)               17954 non-null  int64
#  14  work_rate                      17954 non-null  object
#  15  release_clause_euro            17954 non-null  float64
#  16  club_team                      17940 non-null  object
# dtypes: float64(5), int64(6), object(6)
# memory usage: 2.5+ MB

# %%
data.isna().sum()
# Out:
# name                              0
# age                               0
# height_cm                         0
# weight_kgs                        0
# positions                         0
# nationality                       0
# overall_rating                    0
# potential                         0
# value_euro                        0
# wage_euro                         0
# preferred_foot                    0
# international_reputation(1-5)     0
# weak_foot(1-5)                    0
# skill_moves(1-5)                  0
# work_rate                         0
# release_clause_euro               0
# club_team                        14
# dtype: int64

# %%
data["club_team"].unique
# Out:
# <bound method Series.unique of id
# 158023         FC Barcelona
# 190460    Tottenham Hotspur
# 195864    Manchester United
# 198219               Napoli
# 201024               Napoli
#                 ...
# 204322           Kilmarnock
# 239762             Cracovia
# 235155        SC Heerenveen
# 244883             Al Hilal
# 247187       FC Midtjylland
# Name: club_team, Length: 17954, dtype: object>

# %%
data[pd.isnull(data.club_team)]
# Out:
#                   name  age  height_cm  weight_kgs   positions nationality  \
# id
# 195905    L. Gutiérrez   34     154.94        86.2          CB     Bolivia
# 245169  J. Lalrinzuala   20     175.26        68.0       LB,LM       India
# 236452  D. Lalhlimpuia   21     182.88        76.2       ST,RW       India
# 228192      E. Lyngdoh   32     175.26        68.0      CM,CDM       India
# 221588       A. Mondal   29     152.40        69.9          CB       India
# 193911         S. Paul   32     185.42        78.0          GK       India
# 234507      M. Rafique   26     172.72        67.1          CM       India
# 212502        R. Singh   28     185.42        74.8          ST       India
# 241404        M. Ortíz   29     182.88        83.0      CB,CDM     Bolivia
# 216751     D. Bejarano   27     175.26        69.9  RB,RWB,CDM     Bolivia
# 226044       R. Vargas   24     170.18        64.9          ST     Bolivia
# 234372      C. Machado   28     172.72        69.9         CDM     Bolivia
# 175393         J. Arce   33     175.26        69.9       LM,ST     Bolivia
# 153160       R. Raldes   37     154.94        78.0          CB     Bolivia
#
#         overall_rating  potential  value_euro  wage_euro preferred_foot  \
# id
# 195905              67         67    700000.0     3000.0          Right
# 245169              56         64    700000.0     3000.0           Left
# 236452              54         67    700000.0     3000.0          Right
# 228192              56         56    700000.0     3000.0          Right
# 221588              57         57    700000.0     3000.0          Right
# 193911              57         57    700000.0     3000.0          Right
# 234507              58         61    700000.0     3000.0          Right
# 212502              59         59    700000.0     3000.0           Left
# 241404              65         65    700000.0     3000.0          Right
# 216751              65         65    700000.0     3000.0          Right
# 226044              66         69    700000.0     3000.0          Right
# 234372              66         67    700000.0     3000.0          Right
# 175393              68         68    700000.0     3000.0           Left
# 153160              70         70    700000.0     3000.0          Right
#
#         international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  \
# id
# 195905                              1               3                 2
# 245169                              1               2                 2
# 236452                              1               3                 2
# 228192                              1               3                 2
# 221588                              1               3                 2
# 193911                              1               3                 1
# 234507                              1               3                 2
# 212502                              1               3                 2
# 241404                              1               4                 2
# 216751                              1               2                 2
# 226044                              1               4                 3
# 234372                              1               3                 2
# 175393                              1               3                 3
# 153160                              1               3                 2
#
#              work_rate  release_clause_euro club_team
# id
# 195905  Medium/ Medium            1100000.0       NaN
# 245169  Medium/ Medium            1100000.0       NaN
# 236452  Medium/ Medium            1100000.0       NaN
# 228192  Medium/ Medium            1100000.0       NaN
# 221588     Low/ Medium            1100000.0       NaN
# 193911  Medium/ Medium            1100000.0       NaN
# 234507      High/ High            1100000.0       NaN
# 212502  Medium/ Medium            1100000.0       NaN
# 241404  Medium/ Medium            1100000.0       NaN
# 216751  Medium/ Medium            1100000.0       NaN
# 226044       High/ Low            1100000.0       NaN
# 234372    Medium/ High            1100000.0       NaN
# 175393       High/ Low            1100000.0       NaN
# 153160  Medium/ Medium            1100000.0       NaN

# %%
data["club_team"].fillna("No clube", inplace = True)

# %%
data.isna().sum()
# Out:
# name                             0
# age                              0
# height_cm                        0
# weight_kgs                       0
# positions                        0
# nationality                      0
# overall_rating                   0
# potential                        0
# value_euro                       0
# wage_euro                        0
# preferred_foot                   0
# international_reputation(1-5)    0
# weak_foot(1-5)                   0
# skill_moves(1-5)                 0
# work_rate                        0
# release_clause_euro              0
# club_team                        0
# dtype: int64

# %%
data.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kgs', 'positions', 'nationality',
#        'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'international_reputation(1-5)', 'weak_foot(1-5)',
#        'skill_moves(1-5)', 'work_rate', 'release_clause_euro', 'club_team'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
plt.boxplot(data[['age', 'height_cm','weight_kgs','wage_euro']],labels=['age', 'height_cm','weight_kgs','wage_euro'])
plt.title('box plots of the data')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.boxplot(data[['overall_rating', 'potential', 'value_euro']],labels=['overall_rating', 'potential', 'value_euro'])
plt.title('box plots of the data')
plt.show()

# %%
q1=np.percentile(data['wage_euro'],25,interpolation='midpoint')
q2=np.percentile(data['wage_euro'],50,interpolation='midpoint')
q3=np.percentile(data['wage_euro'],75,interpolation='midpoint')

# %%
iqr=q3-q1

lw=q1-1.5*iqr
up=q3+1.5*iqr

# %%
outlier=[]
for x in data['wage_euro']:
    if((x>up)or(x<lw)):
        outlier.append(x)

# %%
ind=(data['wage_euro']>up)|(data['wage_euro']<lw)
dt=data.loc[ind].index
data.drop(dt,inplace=True)

# %%
q1=np.percentile(data['value_euro'],25,interpolation='midpoint')
q2=np.percentile(data['value_euro'],50,interpolation='midpoint')
q3=np.percentile(data['value_euro'],75,interpolation='midpoint')

# %%
iqr=q3-q1
lw=q1-1.5*iqr
up=q3+1.5*iqr

# %%
outlier=[]
for x in data['value_euro']:
    if((x>up)or(x<lw)):
        outlier.append(x)

# %%
ind=(data['value_euro']>up)|(data['value_euro']<lw)
dt=data.loc[ind].index
data.drop(dt,inplace=True)

# %%
q1=np.percentile(data['value_euro'],25,interpolation='midpoint')
q2=np.percentile(data['value_euro'],50,interpolation='midpoint')
q3=np.percentile(data['value_euro'],75,interpolation='midpoint')

# %%
iqr=q3-q1
lw=q1-1.5*iqr
up=q3+1.5*iqr

# %%
outlier=[]
for x in data['age']:
    if((x>up)or(x<lw)):
        outlier.append(x)
ind=(data['age']>up)|(data['age']<lw)
dt=data.loc[ind].index
data.drop(dt,inplace=True)

# %%
plt.figure(figsize=(10,8))
plt.boxplot(data[['age', 'height_cm','weight_kgs','wage_euro']],labels=['age', 'height_cm','weight_kgs','wage_euro'])
plt.title('box plots of the data')
# Out:
# Text(0.5, 1.0, 'box plots of the data')

# %%
plt.figure(figsize=(10,8))
plt.boxplot(data[['overall_rating', 'potential', 'value_euro']],labels=['overall_rating', 'potential', 'value_euro'])
plt.title('box plots of the data')
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kgs', 'positions', 'nationality',
#        'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'international_reputation(1-5)', 'weak_foot(1-5)',
#        'skill_moves(1-5)', 'work_rate', 'release_clause_euro', 'club_team',
#        'euro'],
#       dtype='object')

# %%
data['euro'] = data['value_euro']+ data['wage_euro']

# %%
data.drop(columns=['wage_euro'],axis=1, inplace=True)

# %%
data.head()
# Out:
#                 name  age  height_cm  weight_kgs     positions   nationality  \
# id
# 156713  A. Granqvist   33     193.04        83.9            CB        Sweden
# 214394    W. Barrios   25     152.40        71.2        CDM,CM      Colombia
# 174381    C. Riveros   36     152.40        73.9        CM,CDM      Paraguay
# 225144        P. Tau   24     167.64        64.9  ST,RW,LW,CAM  South Africa
# 177149      B. Jokič   32     175.26        77.1        LWB,LB      Slovenia
#
#         overall_rating  potential  value_euro preferred_foot  \
# id
# 156713              80         80    700000.0          Right
# 214394              78         83    700000.0          Right
# 174381              76         76    700000.0          Right
# 225144              75         81    700000.0          Right
# 177149              75         75    700000.0           Left
#
#         international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  \
# id
# 156713                              2               4                 2
# 214394                              1               3                 3
# 174381                              1               3                 3
# 225144                              1               4                 4
# 177149                              1               3                 2
#
#              work_rate  release_clause_euro     club_team      euro
# id
# 156713    High/ Medium            1100000.0        Sweden  703000.0
# 214394    Medium/ High            1100000.0      Colombia  703000.0
# 174381  Medium/ Medium            1100000.0      Paraguay  703000.0
# 225144    High/ Medium            1100000.0  South Africa  703000.0
# 177149  Medium/ Medium            1100000.0      Slovenia  703000.0

# %%
data['move_rating'] = data['international_reputation(1-5)']+ data['skill_moves(1-5)']

# %%
data.drop(columns=['international_reputation(1-5)','skill_moves(1-5)'],axis=1, inplace=True)

# %%
data.head()
# Out:
#                 name  age  height_cm  weight_kgs     positions   nationality  \
# id
# 156713  A. Granqvist   33     193.04        83.9            CB        Sweden
# 214394    W. Barrios   25     152.40        71.2        CDM,CM      Colombia
# 174381    C. Riveros   36     152.40        73.9        CM,CDM      Paraguay
# 225144        P. Tau   24     167.64        64.9  ST,RW,LW,CAM  South Africa
# 177149      B. Jokič   32     175.26        77.1        LWB,LB      Slovenia
#
#         overall_rating  potential  value_euro preferred_foot  weak_foot(1-5)  \
# id
# 156713              80         80    700000.0          Right               4
# 214394              78         83    700000.0          Right               3
# 174381              76         76    700000.0          Right               3
# 225144              75         81    700000.0          Right               4
# 177149              75         75    700000.0           Left               3
#
#              work_rate  release_clause_euro     club_team      euro  \
# id
# 156713    High/ Medium            1100000.0        Sweden  703000.0
# 214394    Medium/ High            1100000.0      Colombia  703000.0
# 174381  Medium/ Medium            1100000.0      Paraguay  703000.0
# 225144    High/ Medium            1100000.0  South Africa  703000.0
# 177149  Medium/ Medium            1100000.0      Slovenia  703000.0
#
#         move_rating
# id
# 156713            4
# 214394            4
# 174381            4
# 225144            5
# 177149            3

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in data:
    data[i]=le.fit_transform(data[i])

# %%
data.head()
# Out:
#          name  age  height_cm  weight_kgs  positions  nationality  \
# id
# 156713    412   16         14          32         73          135
# 214394  11648    8          0          19        114           29
# 174381   1996   19          0          22        187          112
# 225144   9449    7          6          13        706          128
# 177149   1291   15          9          25        446          127
#
#         overall_rating  potential  value_euro  preferred_foot  weak_foot(1-5)  \
# id
# 156713              33         31          45               1               3
# 214394              31         34          45               1               2
# 174381              29         27          45               1               2
# 225144              28         32          45               1               3
# 177149              28         26          45               0               2
#
#         work_rate  release_clause_euro  club_team  euro  move_rating
# id
# 156713          2                  724        596   282            2
# 214394          6                  724        163   282            2
# 174381          8                  724        448   282            2
# 225144          2                  724        568   282            3
# 177149          8                  724        567   282            1

# %% [markdown]
# EDA

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(data=data,x="age",palette="winter")
plt.title("Distribution of Full Time Result",size=18)
plt.xlabel("age",size=15)
plt.ylabel("name",size=15)
# Out:
# Text(0, 0.5, 'name')

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(data=data,x="age",palette="winter")
plt.title("Distribution of Full Time Result",size=18)
plt.xlabel("age",size=15)
plt.ylabel("name",size=15)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.3,random_state=42)

# %%
X_test
# Out:
#          name  age  height_cm  weight_kgs  positions  nationality  \
# id
# 245469   1041    2         12          23         77          118
# 158667  12050   17         12          34        570           57
# 235317   5962   11         11          26        363           29
# 238951  10591   12          0          18        180           57
# 236750  11810    6          0          15        326          110
# ...       ...  ...        ...         ...        ...          ...
# 228645   7368    7         11          30        689           57
# 215818   3428    5          7           9        181          149
# 171318   3228   14          8          15        381          133
# 246775   8796    4         10          25        326           50
# 230079    567    6          5          14        626           53
#
#         overall_rating  value_euro  preferred_foot  weak_foot(1-5)  work_rate  \
# id
# 245469               7           8               1               1          5
# 158667              16          21               1               1          8
# 235317              23          65               0               2          1
# 238951              18          38               1               1          8
# 236750              15          34               0               0          8
# ...                ...         ...             ...             ...        ...
# 228645              18          47               1               2          8
# 215818              20          59               1               3          2
# 171318              21          51               0               1          2
# 246775               8          14               1               2          8
# 230079              22          63               1               2          1
#
#         release_clause_euro  club_team  euro  move_rating
# id
# 245469                   92        466    27            1
# 158667                  253        516   101            2
# 235317                  738        193   715            2
# 238951                  590        227   265            1
# 236750                  495        362   216            1
# ...                     ...        ...   ...          ...
# 228645                  726        254   396            1
# 215818                  737         92   611            2
# 171318                  726        221   454            3
# 246775                  164        362    59            2
# 230079                  741        225   682            2
#
# [4173 rows x 15 columns]

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
lr = model.fit(X_train,Y_train)

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([18.54972513, 10.49415359, 22.9790394 , ..., 18.22490951,
#        16.73995677, 26.90175158])

# %%
Y_test
# Out:
# id
# 245469    16
# 158667    14
# 235317    21
# 238951    16
# 236750    19
#           ..
# 228645    22
# 215818    27
# 171318    19
# 246775    17
# 230079    29
# Name: potential, Length: 4173, dtype: int64

# %%
model.score(X_test,Y_test)
# Out:
# 0.7124879040092851

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,y_pred)
# Out:
# 7.332730534054063
